# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import imageio

plt.style.use('bmh')
sns.set(rc={'figure.figsize':(9,6)})

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Import Data

# %% [markdown]
# ##### Population

# %%
population = pd.read_excel('../data/gapminder_population.xlsx',index_col=0)
population.head()
# Out:
#                           1800.0     1810.0     1820.0     1830.0     1840.0  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                           1850.0     1860.0     1870.0     1880.0     1890.0  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
# ...

# %%
population.isna().sum()
# Out:
# 1800.0    46
# 1810.0    46
# 1820.0    46
# 1830.0    46
# 1840.0    46
#           ..
# 2011.0    42
# 2012.0    42
# 2013.0    42
# 2014.0    44
# 2015.0    44
# Length: 81, dtype: int64

# %%
population.columns
# Out:
# Float64Index([1800.0, 1810.0, 1820.0, 1830.0, 1840.0, 1850.0, 1860.0, 1870.0,
#               1880.0, 1890.0, 1900.0, 1910.0, 1920.0, 1930.0, 1940.0, 1950.0,
#               1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0,
#               1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0,
#               1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0,
#               1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0,
#               1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0,
#               1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0,
#               1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0,
#               2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0,
#               2015.0],
#              dtype='float64')

# %%
# rename population index name
population.index.name='country'
population.head()
# Out:
#                           1800.0     1810.0     1820.0     1830.0     1840.0  \
# country
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                           1850.0     1860.0     1870.0     1880.0     1890.0  \
# country
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
# ...

# %%
# convert the population table into long format
population.reset_index(inplace=True)
population_long = population.melt(id_vars = 'country', var_name = 'year', value_name = 'population')
population_long.head()
# Out:
#                  country    year  population
# 0               Abkhazia  1800.0         NaN
# 1            Afghanistan  1800.0   3280000.0
# 2  Akrotiri and Dhekelia  1800.0         NaN
# 3                Albania  1800.0    410445.0
# 4                Algeria  1800.0   2503218.0

# %% [markdown]
# ##### Life Expectancy

# %%
life_exp = pd.read_excel('../data/gapminder_lifeexpectancy.xlsx',index_col=0)
life_exp.head()
# Out:
#                        1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  1806.0  \
# Life expectancy
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan             28.21   28.20   28.19   28.18   28.17   28.16   28.15
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40   35.40   35.40   35.40   35.40
# Algeria                 28.82   28.82   28.82   28.82   28.82   28.82   28.82
#
#                        1807.0  1808.0  1809.0  ...  2007.0  2008.0  2009.0  \
# Life expectancy                                ...
# Abkhazia                  NaN     NaN     NaN  ...     NaN     NaN     NaN
# Afghanistan             28.14   28.13   28.12  ...    52.4    52.8    53.3
# Akrotiri and Dhekelia     NaN     NaN     NaN  ...     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40  ...    76.6    76.8    77.0
# ...

# %%
life_exp.isna().sum()
# Out:
# 1800.0    59
# 1801.0    59
# 1802.0    59
# 1803.0    59
# 1804.0    59
#           ..
# 2012.0    52
# 2013.0    52
# 2014.0    52
# 2015.0    52
# 2016.0    52
# Length: 217, dtype: int64

# %%
life_exp.columns
# Out:
# Float64Index([1800.0, 1801.0, 1802.0, 1803.0, 1804.0, 1805.0, 1806.0, 1807.0,
#               1808.0, 1809.0,
#               ...
#               2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0,
#               2015.0, 2016.0],
#              dtype='float64', length=217)

# %%
# rename life exp index name
life_exp.index.name='country'
life_exp.head()
# Out:
#                        1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  1806.0  \
# country
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan             28.21   28.20   28.19   28.18   28.17   28.16   28.15
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40   35.40   35.40   35.40   35.40
# Algeria                 28.82   28.82   28.82   28.82   28.82   28.82   28.82
#
#                        1807.0  1808.0  1809.0  ...  2007.0  2008.0  2009.0  \
# country                                        ...
# Abkhazia                  NaN     NaN     NaN  ...     NaN     NaN     NaN
# Afghanistan             28.14   28.13   28.12  ...    52.4    52.8    53.3
# Akrotiri and Dhekelia     NaN     NaN     NaN  ...     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40  ...    76.6    76.8    77.0
# ...

# %%
# convert the life expectancy table into long format
life_exp.reset_index(inplace=True)
life_exp_long = life_exp.melt(id_vars = 'country', var_name = 'year', value_name = 'life_expectancy')
life_exp_long.head()
# Out:
#                  country    year  life_expectancy
# 0               Abkhazia  1800.0              NaN
# 1            Afghanistan  1800.0            28.21
# 2  Akrotiri and Dhekelia  1800.0              NaN
# 3                Albania  1800.0            35.40
# 4                Algeria  1800.0            28.82

# %% [markdown]
# ##### Fertility

# %%
fertility = pd.read_csv('../data/gapminder_total_fertility.csv',index_col=0)
fertility.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
fertility.isna().sum()
# Out:
# 1800    59
# 1801    59
# 1802    59
# 1803    59
# 1804    59
#         ..
# 2011    59
# 2012    59
# 2013    59
# 2014    61
# 2015    61
# Length: 216, dtype: int64

# %%
fertility.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
# convert fertility columns to int type
fertility.columns = fertility.columns.astype(int)
fertility.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
# rename fertility index name
fertility.index.name='country'
fertility.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# country
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# country                      ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
# convert the fertility table into long format
fertility.reset_index(inplace=True)
fertility_long = fertility.melt(id_vars = 'country', var_name = 'year', value_name = 'fertility_rate')
fertility_long.head()
# Out:
#                  country  year  fertility_rate
# 0               Abkhazia  1800             NaN
# 1            Afghanistan  1800            7.00
# 2  Akrotiri and Dhekelia  1800             NaN
# 3                Albania  1800            4.60
# 4                Algeria  1800            6.99

# %% [markdown]
# ##### Continents

# %%
continents = pd.read_csv('../data/continents.csv',sep=';')
continents.head()
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %% [markdown]
# ### Merge Tables

# %%
df = pd.merge(fertility_long, life_exp_long, how = 'outer', on = ['country','year'])
df.head()
# Out:
# /Users/milad/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)
#                  country    year  fertility_rate  life_expectancy
# 0               Abkhazia  1800.0             NaN              NaN
# 1            Afghanistan  1800.0            7.00            28.21
# 2  Akrotiri and Dhekelia  1800.0             NaN              NaN
# 3                Albania  1800.0            4.60            35.40
# 4                Algeria  1800.0            6.99            28.82

# %%
df = pd.merge(df,population_long, how='outer',on= ['country','year'] )
df.head()
# Out:
# /Users/milad/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)
#                  country    year  fertility_rate  life_expectancy  population
# 0               Abkhazia  1800.0             NaN              NaN         NaN
# 1            Afghanistan  1800.0            7.00            28.21   3280000.0
# 2  Akrotiri and Dhekelia  1800.0             NaN              NaN         NaN
# 3                Albania  1800.0            4.60            35.40    410445.0
# 4                Algeria  1800.0            6.99            28.82   2503218.0

# %%
df = pd.merge(df,continents,how ='inner',on='country')
df.head()
# Out:
#        country    year  fertility_rate  life_expectancy  population continent
# 0  Afghanistan  1800.0             7.0            28.21   3280000.0      Asia
# 1  Afghanistan  1801.0             7.0            28.20         NaN      Asia
# 2  Afghanistan  1802.0             7.0            28.19         NaN      Asia
# 3  Afghanistan  1803.0             7.0            28.18         NaN      Asia
# 4  Afghanistan  1804.0             7.0            28.17         NaN      Asia

# %%
df.dropna(inplace=True)
df.head()
# Out:
#         country    year  fertility_rate  life_expectancy  population continent
# 0   Afghanistan  1800.0             7.0            28.21   3280000.0      Asia
# 10  Afghanistan  1810.0             7.0            28.11   3280000.0      Asia
# 20  Afghanistan  1820.0             7.0            28.01   3323519.0      Asia
# 30  Afghanistan  1830.0             7.0            27.90   3448982.0      Asia
# 40  Afghanistan  1840.0             7.0            27.80   3625022.0      Asia

# %% [markdown]
# ### Exploratory Data Analysis(EDA)

# %% [markdown]
# #### Fertility Analysis

# %% [markdown]
# comparsion of fertility of 4 countries at 1960

# %%
subset = df[df['country'].isin(['Iran','Germany','China','Afghanistan'])]
subset.head()
# Out:
#         country    year  fertility_rate  life_expectancy  population continent
# 0   Afghanistan  1800.0             7.0            28.21   3280000.0      Asia
# 10  Afghanistan  1810.0             7.0            28.11   3280000.0      Asia
# 20  Afghanistan  1820.0             7.0            28.01   3323519.0      Asia
# 30  Afghanistan  1830.0             7.0            27.90   3448982.0      Asia
# 40  Afghanistan  1840.0             7.0            27.80   3625022.0      Asia

# %%
subset_1960 = subset.loc[(subset['year'] == 1960)]
sns.barplot(data=subset_1960,x='country',y='fertility_rate');

# %% [markdown]
# comparsion of the fertility of the 4 countries for 3 years

# %%
subset_three_years = subset.loc[(subset['year'].isin([1989,2000,2015]) )]
sns.barplot(data=subset_three_years,x='country',y='fertility_rate',hue='year');

# %%
sns.barplot(data=subset_three_years,x='year',y='fertility_rate',hue='country');

# %% [markdown]
# comparsion of the fertility of 4 countries between 1800-2015

# %%
sns.lineplot(data=subset, x='year', y='fertility_rate', hue='country');

# %% [markdown]
# #### Life Expectancy Analysis

# %% [markdown]
# Draw a histogram of life expectancies for the year 2015

# %%
subset_2015 = df.loc[(df['year'] == 2015)]
sns.histplot(data=subset_2015,x='life_expectancy',bins=20)
plt.title('Histogram of life expectancies for the year 2015')
plt.xlabel("Life expectancy")
plt.ylabel("Frequnecy")
plt.axis([40,90,0,25]);

# %% [markdown]
# #### Populatuin Analysis

# %% [markdown]
# compare population of each continet in 2015

# %%
subset_2015.groupby('continent')[['population']].sum()/(1_000_000_000)
# Out:
#                        population
# continent
# Africa                   1.049467
# Asia                     4.196161
# Australia and Oceania    0.038269
# Europe                   0.604907
# North America            0.568107
# South America            0.418176

# %%
def sum_in_billion(x):
    return sum(x)/1_000_000_000

# %%
sns.barplot(data=subset_2015,x='continent',y='population',estimator=sum_in_billion);

# %% [markdown]
# compare population of each continet between 1800-2015

# %%
sns.lineplot(data=df, x='year', y='population', hue='continent',estimator=sum_in_billion);

# %% [markdown]
# #### General Analysis

# %% [markdown]
# plot correlation between life expectancy and fertility for 2000

# %%
subset_2000 = df.loc[(df['year'] == 2000)]

# %%
sns.scatterplot(data=subset_2000,x='life_expectancy',y='fertility_rate');

# %% [markdown]
# create an animated scatterplot

# %%
# plot and save correlation between life expectancy and fertility for years between 1960-2015
for year in range(1960,2016):
    subset = df.loc[df['year'] == year]
    ax = sns.scatterplot(data=subset,x='life_expectancy',y='fertility_rate', hue='continent',
                        alpha=0.6,size =subset['population']//10_000,sizes=(10,1000))
    
    handles, labels  =  ax.get_legend_handles_labels()
    plt.axis((0,100,0,10))
    plt.title("Correlation between life expentency and fertility rate for year = %s" % str(year))
    plt.xlabel('Life Expectancy')
    plt.ylabel('Fertility Rate')
    ax.legend(handles,labels[0:7],loc = 'center left',bbox_to_anchor=(1, 0.5),fontsize=13)
    plt.savefig('../figures/life_exp/life_exp_%s.png' %str(year),bbox_inches='tight')
    plt.close()

# %%
# generate gif file
images = []

for i in range(1960, 2016):
    filename = '../figures/life_exp/life_exp_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('../figures/animation.gif', images, fps=10)

# %%
# save df for future usage
df.to_csv('../data/data.csv')

# %% [markdown]
# ### Visualizing Using Bokeh

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource, CategoricalColorMapper
from bokeh.palettes import Spectral6
from bokeh.models import Slider
from bokeh.layouts import column, row
from bokeh.io import curdoc

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2952">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# plot correlation between life expectancy and fertility for 2000

# %%
year = 2000

subset = df.loc[df['year'] == year]

fertility_rate = subset['fertility_rate']
life_expectancy = subset['life_expectancy']

# Create the figure: p
p = figure(title = f'Correlation between life expentency and fertility rate for year {year}',plot_height=600,plot_width=900, x_axis_label='life_expectancy', y_axis_label='fertility_rate')

# Add a circle glyph to the figure p
p.circle(life_expectancy, fertility_rate)


# Display the plot
show(p)
# Out:
#   <div class="bk-root" id="db10fbce-f9eb-4c84-9444-6fc586b404d9" data-root-id="4039"></div>

# %% [markdown]
# make the plot fancier by considering the size of bubbles regarding the population and colorizing bubbles regarding the continent

# %%
year = 2000

subset = df.loc[df['year'] == year]
subset['population'] = subset['population']//15000000

source = ColumnDataSource(subset)

# Define collormapper
mapper = CategoricalColorMapper( factors = list(subset['continent'].unique()),
                                 palette=Spectral6)

# Create the figure: p
p = figure(title = f'Correlation between life expentency and fertility rate for year {year}',plot_height=600,plot_width=900, x_axis_label='life_expectancy', y_axis_label='fertility_rate')



# Add a circle glyph to the figure p
p.circle('life_expectancy', 'fertility_rate', size = 'population',fill_alpha=0.6,
         source=source,color={'field': 'continent', 'transform': mapper},legend_field='continent')
p.legend.location = 'bottom_left'


# Display the plot
show(p)
# Out:
# /var/folders/5s/6pgy7nbj33505jlm306sn_480000gn/T/ipykernel_64005/355267074.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['population'] = subset['population']//15000000
#   <div class="bk-root" id="a2f36cdf-79f4-4678-b6dd-9f96e005e551" data-root-id="3657"></div>
